# %% [markdown]
# <a href="https://colab.research.google.com/github/Deb-bee/Deb-bee/blob/main/NETFLIX_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Define data for the Netflix dataset
data = {
    "show_id": ["s1", "s2", "s3", "s4", "s5", "s6", "s7", "s8", "s9", "s10"],
    "type": ["Movie", "Movie", "TV Show", "Movie", "TV Show", "Movie", "Movie", "TV Show", "Movie", "Movie"],
    "title": [
        "The Matrix",
        "Titanic",
        "Friends",
        "Jurassic Park",
        "The X-Files",
        "Pulp Fiction",
        "Forrest Gump",
        "Seinfeld",
        "The Lion King",
        "Goodfellas"
    ],
    "director": [
        "Lana Wachowski, Lilly Wachowski",
        "James Cameron",
        None,
        "Steven Spielberg",
        None,
        "Quentin Tarantino",
        "Robert Zemeckis",
        None,
        "Roger Allers, Rob Minkoff",
        "Martin Scorsese"
    ],
    "cast": [
        "Keanu Reeves, Laurence Fishburne, Carrie-Anne Moss",
        "Leonardo DiCaprio, Kate Winslet",
        "Jennifer Aniston, Courteney Cox, Lisa Kudrow",
        "Sam Neill, Laura Dern, Jeff Goldblum",
        "David Duchovny, Gillian Anderson",
        "John Travolta, Uma Thurman, Samuel L. Jackson",
        "Tom Hanks, Robin Wright, Gary Sinise",
        "Jerry Seinfeld, Julia Louis-Dreyfus, Michael Richards",
        "Matthew Broderick, Jeremy Irons, James Earl Jones",
        "Robert De Niro, Ray Liotta, Joe Pesci"
    ],
    "country": [
        "United States",
        "United States",
        "United States",
        "United States",
        "United States",
        "United States",
        "United States",
        "United States",
        "United States",
        "United States"
    ],
    "date_added": [
        "2020-01-01",
        "2020-02-15",
        "2020-03-01",
        "2020-04-10",
        "2020-05-20",
        "2020-06-15",
        "2020-07-01",
        "2020-08-10",
        "2020-09-05",
        "2020-10-01"
    ],
    "release_year": [1999, 1997, 1994, 1993, 1993, 1994, 1994, 1989, 1994, 1990],
    "duration": [
        "136 min",
        "195 min",
        "10 Seasons",
        "127 min",
        "11 Seasons",
        "154 min",
        "142 min",
        "9 Seasons",
        "88 min",
        "146 min"
    ],
    "genre": [
        "Sci-Fi & Fantasy",
        "Romance, Drama",
        "Comedy",
        "Adventure, Sci-Fi",
        "Mystery, Sci-Fi",
        "Crime, Drama",
        "Drama",
        "Comedy",
        "Animation, Family",
        "Crime, Drama"
    ],
    "description": [
        "A computer hacker learns about the true nature of his reality and his role in the war against its controllers.",
        "A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.",
        "Follows the personal and professional lives of six twenty to thirty-something-year-old friends living in Manhattan.",
        "During a preview tour, a theme park suffers a major power breakdown that allows its cloned dinosaur exhibits to run amok.",
        "Two FBI agents investigate strange and unexplained phenomena.",
        "The lives of two mob hitmen, a boxer, a gangster's wife, and a pair of diner bandits intertwine in four tales of violence and redemption.",
        "The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal, and other historical events unfold from the perspective of an Alabama man with an IQ of 75.",
        "The continuing misadventures of neurotic New York City stand-up comedian Jerry Seinfeld and his equally neurotic friends.",
        "Lion cub and future king Simba searches for his identity. His eagerness to please others and penchant for testing his boundaries sometimes gets him into trouble.",
        "The story of Henry Hill and his life in the mob, covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito."
    ]
}

# Create a DataFrame
netflix_df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
netflix_df.to_csv("netflix_data.csv", index=False)

# Print confirmation
print("Netflix dataset with 'Genre' column has been created and saved as 'netflix_data.csv'.")
# Out:
# Netflix dataset with 'Genre' column has been created and saved as 'netflix_data.csv'.

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")
netflix_df.head()
# Out:
#   show_id     type          title                         director  \
# 0      s1    Movie     The Matrix  Lana Wachowski, Lilly Wachowski
# 1      s2    Movie        Titanic                    James Cameron
# 2      s3  TV Show        Friends                              NaN
# 3      s4    Movie  Jurassic Park                 Steven Spielberg
# 4      s5  TV Show    The X-Files                              NaN
#
#                                                 cast        country  \
# 0  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...  United States
# 1                    Leonardo DiCaprio, Kate Winslet  United States
# 2       Jennifer Aniston, Courteney Cox, Lisa Kudrow  United States
# 3               Sam Neill, Laura Dern, Jeff Goldblum  United States
# 4                   David Duchovny, Gillian Anderson  United States
#
#    date_added  release_year    duration  \
# 0  2020-01-01          1999     136 min
# 1  2020-02-15          1997     195 min
# ...

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       10 non-null     object
#  1   type          10 non-null     object
#  2   title         10 non-null     object
#  3   director      7 non-null      object
#  4   cast          10 non-null     object
#  5   country       10 non-null     object
#  6   date_added    10 non-null     object
#  7   release_year  10 non-null     int64
#  8   duration      10 non-null     object
#  9   description   10 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 932.0+ bytes

# %%
subset = netflix_df["release_year"].between(1990, 1999)
netflix_df = netflix_df[subset]
netflix_df["release_year"].value_counts()
# Out:
# release_year
# 1994    4
# 1993    2
# 1999    1
# 1997    1
# 1990    1
# Name: count, dtype: int64

# %%
plt.hist(netflix_df["release_year"])
plt.xlabel("year")
plt.ylabel("count of movies")
plt.title("Distribution of movies released in the 1990s")
plt.show();

# %%
netflix_df["duration"].value_counts()
# Out:
# duration
# 136 min       1
# 195 min       1
# 10 Seasons    1
# 127 min       1
# 11 Seasons    1
# 154 min       1
# 142 min       1
# 88 min        1
# 146 min       1
# Name: count, dtype: int64

# %%
duration = netflix_df["duration"].mode().sum()
duration
# Out:
# '10 Seasons11 Seasons127 min136 min142 min146 min154 min195 min88 min9 Seasons'

# %%
netflix_df["genre"].value_counts()
# Out:
# genre
# Comedy               2
# Crime, Drama         2
# Sci-Fi & Fantasy     1
# Romance, Drama       1
# Adventure, Sci-Fi    1
# Mystery, Sci-Fi      1
# Drama                1
# Animation, Family    1
# Name: count, dtype: int64

# %%
netflix_df["genre"].value_counts().plot(kind = "bar", figsize = (16,8), rot=0)
# Out:
# <Axes: xlabel='genre'>
